# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import astropy.constants as c
import astropy.units as u
import sys
from scipy.interpolate import spline
from matplotlib.ticker import MultipleLocator
import cPickle



sys.path.insert(0, '../')
from matplotlib.colors import LogNorm
from six.moves import cPickle as pickle

import pyathena as pa


unit = pa.set_units(muH=1.4271)
#print (unit['density'].cgs / 1.4271 / c.m_p.cgs, unit['velocity'], unit['length'])

# other units can be easily obtained
#print (unit['mass'], unit['time'], unit['magnetic_field'])

Msun = unit['mass'].to('Msun').value
print Msun
Myr=unit['time'].to('Myr').value

agebin = 10 # unit : Myr, 10 : H-alpha like, 40 : cluster lifetime

M_T_0 = []
M_T_1 = []
M_T_2 = []

simid_t = ('RPS_8pc_noICM_newacc','RPS_8pc_ICM0_newacc','RPS_8pc_ICM1_newacc','RPS_8pc_ICM2_newacc','RPS_8pc_ICM3_newacc') # 'MHD_8pc_new' ,
labell = ('NoICM','ICM0','ICM1','ICM2','ICM3') # r'No ICM',
#C = ('k',(1,0.796,0.224),(1,0.506,0.035),(0.871,0.0,0.102),'deepskyblue','blue','navy')#('k','plum','orchid','purple','deepskyblue','royalblue','navy')#'lightgreen','forestgreen','darkgreen') #'darkkhaki','royalblue','firebrick'
C = ('k','lightsalmon','salmon','deepskyblue','skyblue','royalblue','crimson')
S = ('--','-','-','-','-','-','-')
#L = (1.5,1.5,1.5)
lw = (4,3,2.5,2,3,2.5,2)
alpha = (0.5,1,1,1,0.8,1,1)
# overplot Starformation rate of three different simulations
start = 250
stop = 500
plt.figure(figsize=(11,5))
# Out:
# 0.0352682242985

# %%
for j,name in enumerate(labell) :
    #print j,name
    basedir = 'G:/yeongu/'
    simid = simid_t[j]
    Mj = []
    M_star_c = 0.0
    Mass_tot = []
    Mc = []
    SFE = []
    if j == 4:
        stop = 473
    elif j == 6:
        stop = 401
    else:
        stop = 499
    #plt.figure(figsize=(13,5))    
    for tidx in range(250, stop):
        plt.figure(figsize=(11,5))
        vtkfname = '%s%s/id0/%s.%04d.vtk' % (basedir,simid, simid, tidx)

        starfname = vtkfname.replace('id0', 'starpar').replace('vtk', 'starpar.vtk')
        sp = pa.read_starvtk(starfname)

        print(tidx)
        star_clu = sp[sp['mass'] != 0]  # choose cluster, if choose 'mass' = 0, it means runaway star
        star_clu2 = star_clu[star_clu['age'] * Myr < agebin]


        M_star_c += sum(star_clu2['mass'])*Msun # mass sum in time scale / cumulative
        M_star = sum(star_clu2['mass']) * Msun # SFR time variation

        Mj.append(M_star* unit['time'].value / (1e+6*agebin*1.024*1.024)) #* unit['time'].value/ mass divided by time scale & area
        Mc.append(M_star_c* unit['time'].value / (1e+6*agebin*1.024*1.024)) #* unit['time'].value/ mass divided by time scale & area

        #sfe = M_star* unit['time'].value / (1e+6*agebin*1.024*1.024)/surf_mass
        #SFE.append(sfe)


        print j
        ut = round(unit['time'].value,2)
        xx = np.arange(start, stop)*ut
        ml = MultipleLocator(5)
        
        # SFR
        ax1=plt.subplot(1,2,1) 
        plt.minorticks_on()
        ax1.tick_params(which='minor', direction='in')
        ax1.tick_params(which='major', direction='in', labelsize=16)
        plt.plot(Mj,label='%s' % labell[j], color=C[j],linewidth=lw[j],alpha=alpha[j],ls=S[j])
        
        plt.xlim(0,250)
        plt.ylim(0, 0.019)
        plt.xlabel(r'time [Myr]', fontsize=16)
        plt.ylabel(r'$\Sigma_{SFR}$ [M$_{\odot}$ kpc$^{-2}$ yr$^{-1}$]',fontsize=19) # For SFR
        plt.xticks([(250/Myr-250),(300/Myr-250),(350/Myr-250),(400/Myr-250),(450/Myr-250)],[250,300,350,400,450])
        plt.yticks([0,0.004,0.008,0.012,0.016]) # For SFR
        
        # Cumulative
        ax2=plt.subplot(1,2,2)
        plt.minorticks_on()
        ax2.tick_params(which='minor', direction='in')
        ax2.tick_params(which='major', direction='in', labelsize=16)
        plt.plot(Mc,label='%s' % labell[j], color=C[j],linewidth=lw[j],alpha=alpha[j],ls=S[j])
        
        plt.xlim(0,250)
        plt.ylim(0, 1.1)  # For cumulative
        plt.xlabel(r'time [Myr]', fontsize=16)
        plt.ylabel(r'$\Sigma_{\star}$ [M$_{\odot}$ pc$^{-2}$]', fontsize=19)  # For cumulative
        plt.xticks([(250/Myr-250),(300/Myr-250),(350/Myr-250),(400/Myr-250),(450/Myr-250)],[250,300,350,400,450])
        plt.legend(loc=0, fontsize=17)
    
        plt.tight_layout(pad=0.3)
        #plt.show()
        #plt.savefig('D:/yeongu/plots/sfr_time/%s_new/SFR_%s_%s.png' % (name,name,tidx), dpi=100)
        plt.close()
# Out:
# 250
# 0
# 251
# 0
# 252
# 0
# 253
# 0
# 254
# 0
# 255
# 0
# 256
# 0
# 257
# 0
# 258
# 0
# 259
# 0
# 260
# 0
# 261
# 0
# 262
# 0
# 263
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a705cb59734b> in <module>()
#      70         plt.legend(loc=0, fontsize=17)
#      71
# ---> 72         plt.tight_layout(pad=0.3)
#      73         #plt.show()
#      74         #plt.savefig('D:/yeongu/plots/sfr_time/%s_new/SFR_%s_%s.png' % (name,name,tidx), dpi=100)
#
# C:\anaconda2\lib\site-packages\matplotlib\pyplot.pyc in tight_layout(pad, h_pad, w_pad, rect)
#    1350     """
#    1351     fig = gcf()
# -> 1352     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1353
#    1354
#
# C:\anaconda2\lib\site-packages\matplotlib\figure.pyc in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2305         kwargs = get_tight_layout_figure(
#    2306             self, self.axes, subplotspec_list, renderer,
# -> 2307             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2308         self.subplots_adjust(**kwargs)
#    2309
#
# C:\anaconda2\lib\site-packages\matplotlib\tight_layout.pyc in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     347                                      subplot_list=subplot_list,
#     348                                      ax_bbox_list=ax_bbox_list,
# --> 349                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     350
#     351     if rect is not None:
#
# C:\anaconda2\lib\site-packages\matplotlib\tight_layout.pyc in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     113
#     114         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 115                                 if ax.get_visible()])
#     116         tight_bbox = TransformedBbox(tight_bbox_raw,
#     117                                      fig.transFigure.inverted())
#
# C:\anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in get_tightbbox(self, renderer, call_axes_locator)
#    4200             bb.append(bb_xaxis)
#    4201
# -> 4202         bb_yaxis = self.yaxis.get_tightbbox(renderer)
#    4203         if bb_yaxis:
#    4204             bb.append(bb_yaxis)
#
# C:\anaconda2\lib\site-packages\matplotlib\axis.pyc in get_tightbbox(self, renderer)
#    1158         for a in [self.label, self.offsetText]:
#    1159             if a.get_visible():
# -> 1160                 bb.append(a.get_window_extent(renderer))
#    1161
#    1162         bb.extend(ticklabelBoxes)
#
# C:\anaconda2\lib\site-packages\matplotlib\text.pyc in get_window_extent(self, renderer, dpi)
#     920             raise RuntimeError('Cannot get window extent w/o renderer')
#     921
# --> 922         bbox, info, descent = self._get_layout(self._renderer)
#     923         x, y = self.get_unitless_position()
#     924         x, y = self.get_transform().transform_point((x, y))
#
# C:\anaconda2\lib\site-packages\matplotlib\text.pyc in _get_layout(self, renderer)
#     307                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     308                                                         self._fontproperties,
# --> 309                                                         ismath=ismath)
#     310             else:
#     311                 w, h, d = 0, 0, 0
#
# C:\anaconda2\lib\site-packages\matplotlib\backends\backend_agg.pyc in get_text_width_height_descent(self, s, prop, ismath)
#     239         if ismath:
#     240             ox, oy, width, height, descent, fonts, used_characters = \
# --> 241                 self.mathtext_parser.parse(s, self.dpi, prop)
#     242             return width, height, descent
#     243
#
# C:\anaconda2\lib\site-packages\matplotlib\mathtext.pyc in parse(self, s, dpi, prop)
#    3291             self.__class__._parser = Parser()
#    3292
# -> 3293         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3294         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3295         result = font_output.get_results(box)
#
# C:\anaconda2\lib\site-packages\matplotlib\mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2513         self._em_width_cache = {}
#    2514         try:
# -> 2515             result = self._expression.parseString(s)
#    2516         except ParseBaseException as err:
#    2517             raise ValueError("\n".join([
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseString(self, instring, parseAll)
#    1620             instring = instring.expandtabs()
#    1621         try:
# -> 1622             loc, tokens = self._parse( instring, 0 )
#    1623             if parseAll:
#    1624                 loc = self.preParse( instring, loc )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3393                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3394             else:
# -> 3395                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3396             if exprtokens or exprtokens.haskeys():
#    3397                 resultlist += exprtokens
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3917     def parseImpl( self, instring, loc, doActions=True ):
#    3918         try:
# -> 3919             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    3920         except (ParseException,IndexError):
#    3921             return loc, []
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3856                 else:
#    3857                     preloc = loc
# -> 3858                 loc, tmptokens = self_expr_parse( instring, preloc, doActions )
#    3859                 if tmptokens or tmptokens.haskeys():
#    3860                     tokens += tmptokens
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3376         # pass False as last arg to _parse for first element, since we already
#    3377         # pre-parsed the string as part of our And pre-parsing
# -> 3378         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3379         errorStop = False
#    3380         for e in self.exprs[1:]:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1403             else:
#    1404                 for fn in self.parseAction:
# -> 1405                     tokens = fn( instring, tokensStart, retTokens )
#    1406                     if tokens is not None:
#    1407                         retTokens = ParseResults( tokens,
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in wrapper(*args)
#    1047         while 1:
#    1048             try:
# -> 1049                 ret = func(*args[limit[0]:])
#    1050                 foundArity[0] = True
#    1051                 return ret
#
# C:\anaconda2\lib\site-packages\matplotlib\mathtext.pyc in math_string(self, s, loc, toks)
#    2582
#    2583     def math_string(self, s, loc, toks):
# -> 2584         return self._math_expression.parseString(toks[0][1:-1])
#    2585
#    2586     def math(self, s, loc, toks):
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseString(self, instring, parseAll)
#    1620             instring = instring.expandtabs()
#    1621         try:
# -> 1622             loc, tokens = self._parse( instring, 0 )
#    1623             if parseAll:
#    1624                 loc = self.preParse( instring, loc )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3846         if check_ender:
#    3847             try_not_ender(instring, loc)
# -> 3848         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    3849         try:
#    3850             hasIgnoreExprs = (not not self.ignoreExprs)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3393                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3394             else:
# -> 3395                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3396             if exprtokens or exprtokens.haskeys():
#    3397                 resultlist += exprtokens
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3846         if check_ender:
#    3847             try_not_ender(instring, loc)
# -> 3848         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    3849         try:
#    3850             hasIgnoreExprs = (not not self.ignoreExprs)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3384             if errorStop:
#    3385                 try:
# -> 3386                     loc, exprtokens = e._parse( instring, loc, doActions )
#    3387                 except ParseSyntaxException:
#    3388                     raise
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3393                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3394             else:
# -> 3395                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3396             if exprtokens or exprtokens.haskeys():
#    3397                 resultlist += exprtokens
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3917     def parseImpl( self, instring, loc, doActions=True ):
#    3918         try:
# -> 3919             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    3920         except (ParseException,IndexError):
#    3921             return loc, []
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3856                 else:
#    3857                     preloc = loc
# -> 3858                 loc, tmptokens = self_expr_parse( instring, preloc, doActions )
#    3859                 if tmptokens or tmptokens.haskeys():
#    3860                     tokens += tmptokens
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3376         # pass False as last arg to _parse for first element, since we already
#    3377         # pre-parsed the string as part of our And pre-parsing
# -> 3378         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3379         errorStop = False
#    3380         for e in self.exprs[1:]:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3981     def parseImpl( self, instring, loc, doActions=True ):
#    3982         try:
# -> 3983             loc, tokens = self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3984         except (ParseException,IndexError):
#    3985             if self.defaultValue is not _optionalNotMatched:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1527                 ParserElement.packrat_cache_stats[MISS] += 1
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#    1531                     # cache a copy of the exception, without the traceback
# -> 1532                     cache.set(lookup, pe.__class__(*pe.args))
#    1533                     raise
#    1534                 else:
#
# C:\anaconda2\lib\site-packages\pyparsing.pyc in set(self, key, value)
#    1467                     while len(cache) > size:
#    1468                         try:
# -> 1469                             cache.popitem(False)
#    1470                         except KeyError:
#    1471                             pass
#
# C:\anaconda2\lib\collections.pyc in popitem(self, last)
#     173
#     174         '''
# --> 175         if not self:
#     176             raise KeyError('dictionary is empty')
#     177         key = next(reversed(self) if last else iter(self))
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(7,7))
for j,name in enumerate(labell) :
    #print j,name
    basedir = 'F:/yeongu/'
    simid = simid_t[j]
    Mj = []
    M_star_c = 0.0
    Mass_tot = []
    Mc = []
    SFE = []
    if j == 5:
        stop = 472
    elif j == 6:
        stop = 401
    else:
        stop = 500

    V=[]
    for tidx in range(250, stop):
        #plt.figure(igsize=(11,5))
        vtkfname = '%s%s/id0/%s.%04d.vtk' % (basedir,simid, simid, tidx)

        starfname = vtkfname.replace('id0', 'starpar').replace('vtk', 'starpar.vtk')
        sp = pa.read_starvtk(starfname)
        
        star_clu = sp[sp['mass'] != 0]  # choose cluster, if choose 'mass' = 0, it means runaway star
        #star_clu2 = star_clu[star_clu['age'] * Myr < agebin]
        #print star_clu
        vz = star_clu['v3']
        #print vz
        V.append(np.std(vz))
        
    plt.plot(V,label='%s' % labell[j], color=C[j],linewidth=lw[j],alpha=alpha[j],ls=S[j])
    plt.ylabel('Velocity Std [km/s]')
    plt.xlim(0,250)
    plt.ylim(2,18)
    plt.xticks([(250/Myr-250),(300/Myr-250),(350/Myr-250),(400/Myr-250),(450/Myr-250)],[250,300,350,400,450])
    plt.legend(loc=0)
    plt.savefig('%s_velstd.png' % name)
    #plt.show()
